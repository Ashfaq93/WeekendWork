# %% [markdown]
# Code to scrape yelp iteratvely
# iteration 1: gets all the data on restauant names, phone numbers, addresses, states, number of review and links.

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import pandas
 
#URL = This is the url of the yelp page that you are going to extract data from
dataset = []

for page in range(2):
    URL = ("http://www.yelp.com/search?find_desc=&find_loc=Seattle%2C%20WA&ns=1&start={}".format(page*10))
    driver = webdriver.Chrome()
    driver.get(URL)
    Current_page = driver.page_source
    final_data = []
    soup1 = BeautifulSoup(Current_page,'html.parser')
    all = soup1.find_all('li',{'class':'lemon--li__373c0__1r9wz border-color--default__373c0__2oFDT'})
    for data in all:
        info_scraped = {}
        try:
            base = data.find('h3',{'class':'lemon--h3__373c0__sQmiG heading--h3__373c0__1n4Of alternate__373c0__1uacp'})
            number_sequence = base.text[0]
            if int(number_sequence) in (1.,2.,3.,4.,5.,6.,7.,8.,9.):
                try:
                    info_scraped['Restaurant Name'] = data.find('h3',{'class':'lemon--h3__373c0__sQmiG heading--h3__373c0__1n4Of alternate__373c0__1uacp'}).find('a',{'class':'lemon--a__373c0__IEZFH link__373c0__29943 link-color--blue-dark__373c0__1mhJo link-size--inherit__373c0__2JXk5'}).text
                except:
                    print(None)
                try:
                    info_scraped['Phone Number'] = data.find('div',{'class':'lemon--div__373c0__1mboc container__373c0__19wDx u-padding-l2 border-color--default__373c0__2oFDT text-align--right__373c0__3fmmn'}).find('p',{'class':'lemon--p__373c0__3Qnnj text__373c0__2pB8f text-color--normal__373c0__K_MKN text-align--right__373c0__3ARv7'}).text
                except:
                    print(None)
                try:
                    info_scraped['Address'] = data.find('div',{'class':'lemon--div__373c0__1mboc container__373c0__19wDx u-padding-l2 border-color--default__373c0__2oFDT text-align--right__373c0__3fmmn'}).find('span',{'class':'lemon--span__373c0__3997G'}).text
                except:
                    print(None)
                try:
                    info_scraped['States'] = data.find('div',{'class':'lemon--div__373c0__1mboc container__373c0__19wDx u-padding-l2 border-color--default__373c0__2oFDT text-align--right__373c0__3fmmn'}).find('div',{'class':'lemon--div__373c0__1mboc display--inline-block__373c0__2de_K border-color--default__373c0__2oFDT'}).text
                except:
                    print(None)
                try:
                    info_scraped['Number of Review'] = data.find('div',{'class':'lemon--div__373c0__1mboc attribute__373c0__1hPI_ display--inline-block__373c0__2de_K border-color--default__373c0__2oFDT'}).text
                except:
                    print(None)
                try:
                    info_scraped['Image URL'] = data.find('img',{'class':'lemon--img__373c0__3GQUb photo-box-img__373c0__O0tbt'}).get('src')
                except:
                    print(None)
                try:
                    info_scraped['Category'] = data.find('div',{'class':'lemon--div__373c0__1mboc largerScrollablePhotos__373c0__3FEIJ arrange__373c0__UHqhV border-color--default__373c0__2oFDT'}).find('div',{'class':'lemon--div__373c0__1mboc mainAttributes__373c0__1r0QA arrange-unit__373c0__1piwO arrange-unit-fill__373c0__17z0h border-color--default__373c0__2oFDT'}).find('div',{'class':'lemon--div__373c0__1mboc priceCategory__373c0__3zW0R border-color--default__373c0__2oFDT'}).find('span',{'class':'lemon--span__373c0__3997G display--inline__373c0__1DbOG border-color--default__373c0__2oFDT'}).text
                except:
                    print(None)
                try:
                    info_scraped['link'] = data.find('a',{'class':'lemon--a__373c0__IEZFH link__373c0__29943 link-color--blue-dark__373c0__1mhJo link-size--inherit__373c0__2JXk5'}).get('href')
                except:
                    print(None)
                final_data.append(info_scraped)
        except:
            #final_data.append(info_scraped)
            #print(final_data)
            time.sleep(2)
            continue
    
    dataset.append(final_data)

    
   # driver = webdriver.Chrome()
    #driver.get(URL)
    #yelp_page_source_page1 = driver.page_source

# %%
#soup
#soup.find('h3',{'class':'lemon--h3__373c0__sQmiG heading--h3__373c0__1n4Of alternate__373c0__1uacp'})
#soup.find('div',{'class':'lemon--div__373c0__1mboc container__373c0__19wDx u-padding-l2 border-color--default__373c0__2oFDT text-align--right__373c0__3fmmn'}).text

#soup.find('p',{'class':'lemon--p__373c0__3Qnnj text__373c0__2pB8f text-color--normal__373c0__K_MKN text-align--right__373c0__3ARv7'}).text
#soup.find('div',{'class':'lemon--div__373c0__1mboc mainAttributes__373c0__1r0QA arrange-unit__373c0__1piwO arrange-unit-fill__373c0__17z0h border-color--default__373c0__2oFDT'}).get('src')

soup.find('a',{'class':'lemon--a__373c0__IEZFH link__373c0__29943 link-color--blue-dark__373c0__1mhJo link-size--inherit__373c0__2JXk5'}).get('href')
# Out:
# '/adredir?ad_business_id=NH4mvwM9nwJm420j5UvIeQ&campaign_id=xBFvVeV79xWtsge9yij4zg&click_origin=search_results&placement=above_search&redirect_url=https%3A%2F%2Fwww.yelp.com%2Fbiz%2Fflying-apron-seattle&request_id=7cecbbfcac7c30c7&signature=1691cd5345696fe30dc7d200e8dfae8e4c288cc2acf3a560fd5a2227d5d51cda&slot=0'

# %%
dataset
# Out:
# [[{'Restaurant Name': 'Pike Place Chowder',
#    'Phone Number': '(206) 267-2537',
#    'Address': 'Located in Pike Place Market',
#    'States': 'Downtown',
#    'Number of Review': '6917 reviews',
#    'Image URL': 'https://s3-media3.fl.yelpcdn.com/bphoto/ijju-wYoRAxWjHPTCxyQGQ/ls.jpg',
#    'Category': 'Seafood, Soup'},
#   {'Restaurant Name': 'Piroshky Piroshky',
#    'Phone Number': '(206) 441-6068',
#    'Address': 'Located in Pike Place Market',
#    'States': 'Downtown',
#    'Number of Review': '5888 reviews',
#    'Image URL': 'https://s3-media1.fl.yelpcdn.com/bphoto/Nk1l9zs6LloJVcF9yO8Abg/ls.jpg',
#    'Category': 'Bakeries'},
#   {'Restaurant Name': 'Paseo Caribbean Food - Fremont',
#    'Phone Number': '(206) 545-7440',
#    'Address': '4225 Fremont Ave N',
#    'States': 'Fremont',
#    'Number of Review': '4949 reviews',
#    'Image URL': 'https://s3-media2.fl.yelpcdn.com/bphoto/o5csrmtkMORuMcVBW2dnYg/ls.jpg',
#    'Category': 'Caribbean, Sandwiches, Caterers'},
#   {'Restaurant Name': 'The Pink Door',
#    'Phone Number': '(206) 443-3241',
#    'Address': 'Located in Pike Place Market',
#    'States': 'Downtown',
#    'Number of Review': '4699 reviews',
#    'Image URL': 'https://s3-media3.fl.yelpcdn.com/bphoto/c_vzRF4h3ywnyeM116QFuA/ls.jpg',
#    'Category': 'Italian, Wine Bars, Seafood'},
#   {'Restaurant Name': 'Ellenos Real Greek Yogurt',
#    'Phone Number': '(206) 625-5006',
#    'Address': 'Located in Pike Place Market',
#    'States': 'Downtown',
#    'Number of Review': '1728 reviews',
#    'Image URL': 'https://s3-media2.fl.yelpcdn.com/bphoto/at04j9sEeE7iiZ_U8FkEFQ/ls.jpg',
#    'Category': 'Ice Cream & Frozen Yogurt'},
#   {'Restaurant Name': 'Chihuly Garden and Glass',
#    'Phone Number': '(206) 753-4940',
#    'Address': 'Located in Seattle Center',
#    'States': 'Lower Queen Anne',
#    'Number of Review': '2260 reviews',
#    'Image URL': 'https://s3-media4.fl.yelpcdn.com/bphoto/ap2vNCs6cTSVcrkZqI4VDg/ls.jpg',
#    'Category': 'Art Museums'},
#   {'Restaurant Name': 'Starbucks Reserve Roastery & Tasting Room',
#    'Phone Number': '(206) 624-0173',
#    'Address': '1124 Pike St',
#    'States': 'Capitol Hill',
#    'Number of Review': '2644 reviews',
#    'Image URL': 'https://s3-media3.fl.yelpcdn.com/bphoto/5sWWRhMFHKH6YaKeP2x6XA/ls.jpg',
#    'Category': 'Coffee & Tea, Coffee Roasteries'},
#   {'Restaurant Name': 'The Crumpet Shop',
#    'Phone Number': '(206) 682-1598',
#    'Address': 'Located in Pike Place Market',
#    'States': 'Downtown',
#    'Number of Review': '2211 reviews',
#    'Image URL': 'https://s3-media4.fl.yelpcdn.com/bphoto/nO5iEm4D_m-APyfPf6yv4g/ls.jpg',
#    'Category': 'Bakeries, Coffee & Tea, Breakfast & Brunch'},
#   {'Restaurant Name': 'Lola',
#    'Phone Number': '(206) 441-1430',
#    'Address': 'Located in Hotel Andra',
#    'States': 'Belltown',
#    'Number of Review': '3789 reviews',
#    'Image URL': 'https://s3-media2.fl.yelpcdn.com/bphoto/vtO-PdCHCH5W3sefJRpEmw/ls.jpg',
#    'Category': 'Greek, Mediterranean, Breakfast & Brunch'},
#   {'Restaurant Name': 'Storyville Coffee Company',
#    'Phone Number': '(206) 780-5777',
#    'Address': 'Located in Pike Place Market',
#    'States': 'Downtown',
#    'Number of Review': '1526 reviews',
#    'Image URL': 'https://s3-media3.fl.yelpcdn.com/bphoto/nJgiyjMZ7sglAtc5wyKSLQ/ls.jpg',
#    'Category': 'Coffee & Tea'}],
#  [{'Restaurant Name': 'Japonessa Sushi Cocina',
#    'Phone Number': '(206) 971-7979',
#    'Address': '1400 1st Ave',
#    'States': 'Downtown',
#    'Number of Review': '4466 reviews',
#    'Image URL': 'https://s3-media4.fl.yelpcdn.com/bphoto/vucCrknnlu1RRvRaKWwovQ/ls.jpg',
#    'Category': 'Japanese, Sushi Bars'},
#   {'Restaurant Name': 'Beecher’s Handmade Cheese',
#    'Phone Number': '(206) 956-1964',
#    'Address': 'Located in Pike Place Market',
#    'States': 'Downtown',
#    'Number of Review': '2680 reviews',
#    'Image URL': 'https://s3-media4.fl.yelpcdn.com/bphoto/f6nwbmiNvjLxt7kmXlqDZw/ls.jpg',
#    'Category': 'Cheese Shops, Sandwiches'},
#   {'Restaurant Name': 'Le Panier French Bakery',
#    'Phone Number': '(206) 441-3669',
#    'Address': 'Located in Pike Place Market',
#    'States': 'Downtown',
#    'Number of Review': '2252 reviews',
#    'Image URL': 'https://s3-media1.fl.yelpcdn.com/bphoto/uZ7dSBjL8O1lFbQXx4bHvw/ls.jpg',
#    'Category': 'Bakeries, Sandwiches, Patisserie/Cake Shop'},
#   {'Restaurant Name': 'Serious Pie',
#    'Phone Number': '(206) 838-7388',
#    'Address': '316 Virginia St',
#    'States': 'Belltown',
#    'Number of Review': '4013 reviews',
#    'Image URL': 'https://s3-media3.fl.yelpcdn.com/bphoto/K5cPEhf5ZLkujN73bBNleQ/ls.jpg',
#    'Category': 'Pizza'},
#   {'Restaurant Name': 'Biscuit Bitch',
#    'Phone Number': '(206) 441-7999',
#    'Address': '1909 1st Ave',
#    'States': 'Downtown',
#    'Number of Review': '3483 reviews',
#    'Image URL': 'https://s3-media2.fl.yelpcdn.com/bphoto/I0lyI3zJzC_Y4gxO5HVGxw/ls.jpg',
#    'Category': 'Breakfast & Brunch, Coffee & Tea, Sandwiches'},
#   {'Restaurant Name': 'Tacos Chukis',
#    'Phone Number': '219 Broadway E',
#    'Address': '219 Broadway E',
#    'States': 'Capitol Hill',
#    'Number of Review': '1574 reviews',
#    'Image URL': 'https://s3-media1.fl.yelpcdn.com/bphoto/AU2LRinK4hKGU7nnCTq73Q/ls.jpg',
#    'Category': 'Mexican'},
#   {'Restaurant Name': 'Toulouse Petit Kitchen & Lounge',
#    'Phone Number': '(206) 432-9069',
#    'Address': '601 Queen Anne Ave N',
#    'States': 'Lower Queen Anne',
#    'Number of Review': '3810 reviews',
#    'Image URL': 'https://s3-media4.fl.yelpcdn.com/bphoto/UmEDw1vIvHMNagxlZspJ9A/ls.jpg',
#    'Category': 'Cajun/Creole'},
#   {'Restaurant Name': 'Umi Sake House',
#    'Phone Number': '(206) 374-8717',
#    'Address': '2230 1st Ave',
#    'States': 'Belltown',
#    'Number of Review': '3351 reviews',
#    'Image URL': 'https://s3-media2.fl.yelpcdn.com/bphoto/c-XwgpadB530bjPUAL7oFw/ls.jpg',
#    'Category': 'Sushi Bars, Japanese'},
#   {'Restaurant Name': 'Shiro’s',
#    'Phone Number': '(206) 443-9844',
#    'Address': 'Located in Belltown Court Condos',
#    'States': 'Belltown',
#    'Number of Review': '2055 reviews',
#    'Image URL': 'https://s3-media2.fl.yelpcdn.com/bphoto/f10Z1r4_R95ylcZwUS3LRA/ls.jpg',
#    'Category': 'Sushi Bars, Japanese'},
#   {'Restaurant Name': 'Kerry Park',
#    'Phone Number': '(206) 684-4075',
#    'Address': '211 W Highland Dr',
#    'States': 'Lower Queen Anne',
#    'Number of Review': '871 reviews',
#    'Image URL': 'https://s3-media1.fl.yelpcdn.com/bphoto/SxunHHhqoY44yaIrrrRTRA/ls.jpg',
#    'Category': 'Parks, Playgrounds'}]]

# %%
import pandas as pd
